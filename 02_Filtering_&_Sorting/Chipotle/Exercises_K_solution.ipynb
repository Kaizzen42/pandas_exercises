# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(url, sep='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo['item_price_float'] = chipo['item_price'].str.replace('$','').astype('float')
chipo['item_price_float_per_item'] = chipo['item_price_float'] / chipo['quantity']
item_groups = chipo.groupby('item_name')
max_cost = item_groups.max()
max_cost[max_cost['item_price_float_per_item']>10.00].shape[0]
# Out:
# 25

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
chipo[['item_name','item_price_float_per_item']]
# Out:
#                                   item_name  item_price_float_per_item
# 0              Chips and Fresh Tomato Salsa                       2.39
# 1                                      Izze                       3.39
# 2                          Nantucket Nectar                       3.39
# 3     Chips and Tomatillo-Green Chili Salsa                       2.39
# 4                              Chicken Bowl                       8.49
# ...                                     ...                        ...
# 4617                          Steak Burrito                      11.75
# 4618                          Steak Burrito                      11.75
# 4619                     Chicken Salad Bowl                      11.25
# 4620                     Chicken Salad Bowl                       8.75
# 4621                     Chicken Salad Bowl                       8.75
#
# [4622 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by=['item_name'])
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description item_price  \
# 3389                                        [Diet Coke]    $12.98
# 341                                         [Diet Coke]     $6.49
# 1849                                             [Coke]     $6.49
# 1860                                        [Diet Coke]     $6.49
# 2713                                             [Coke]     $6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
most_expensive_item = max_cost[max_cost['item_price_float_per_item'] == max(max_cost['item_price_float_per_item'])]
most_expensive_item
# chipo['quantity'][]
# Out:
#                      order_id  quantity  \
# item_name
# Barbacoa Salad Bowl      1751         1
# Carnitas Salad Bowl      1692         1
# Steak Salad Bowl         1818         2
#
#                                                     choice_description  \
# item_name
# Barbacoa Salad Bowl  [Tomatillo Red Chili Salsa, [Black Beans, Chee...
# Carnitas Salad Bowl  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...
# Steak Salad Bowl     [Tomatillo Red Chili Salsa, [Rice, Black Beans...
#
#                     item_price  item_price_float  item_price_float_per_item
# item_name
# Barbacoa Salad Bowl     $9.39              11.89                      11.89
# Carnitas Salad Bowl     $9.39              11.89                      11.89
# Steak Salad Bowl        $9.39              23.78                      11.89

# %%
chipo[['item_name','item_price_float_per_item']][chipo['item_price_float_per_item'] == max(chipo['item_price_float_per_item'])]
# Out:
#                 item_name  item_price_float_per_item
# 281      Steak Salad Bowl                      11.89
# 606      Steak Salad Bowl                      11.89
# 613      Steak Salad Bowl                      11.89
# 749      Steak Salad Bowl                      11.89
# 1132  Carnitas Salad Bowl                      11.89
# 1159     Steak Salad Bowl                      11.89
# 1229  Barbacoa Salad Bowl                      11.89
# 1311     Steak Salad Bowl                      11.89
# 1326  Barbacoa Salad Bowl                      11.89
# 1505     Steak Salad Bowl                      11.89
# 1571     Steak Salad Bowl                      11.89
# 1590     Steak Salad Bowl                      11.89
# 1816     Steak Salad Bowl                      11.89
# 2401     Steak Salad Bowl                      11.89
# 2439     Steak Salad Bowl                      11.89
# 2442  Barbacoa Salad Bowl                      11.89
# 2610  Carnitas Salad Bowl                      11.89
# ...

# %%
chipo[chipo.order_id == 1443]
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3599      1443         7                 Bottled Water
# 3600      1443         1             6 Pack Soft Drink
# 3601      1443         3                Veggie Burrito
# 3602      1443         4               Chicken Burrito
# 3603      1443         3                 Steak Burrito
# 3604      1443         2                 Bottled Water
#
#                                      choice_description item_price  \
# 3598                                                NaN    $44.25
# 3599                                                NaN    $10.50
# 3600                                             [Coke]     $6.49
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $33.75
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $35.00
# 3603  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $27.75
# ...

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo[chipo['item_name']=='Veggie Salad Bowl'].shape[0]
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo[(chipo['item_name'] == "Canned Soda") & (chipo['quantity'] > 1)].shape[0]
# Out:
# 20
